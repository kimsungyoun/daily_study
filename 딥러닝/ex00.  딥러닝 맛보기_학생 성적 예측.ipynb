# %% [markdown]
# ### 첫번째 시간입니다
# - 하이~

# %% [markdown]
# ###목표
# - 학생들의 수학성적을 예측하는 회귀 모델을 만들어보자
# - keras를 이용해 신경망을 구성하는 방법을 익혀보자

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 현재 작업 경로 출력
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/sw캠프 데이터 비즈니스 과정
# Out:
# /content/drive/MyDrive/sw캠프 데이터 비즈니스 과정

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/sw캠프 데이터 비즈니스 과정'

# %%
# 모든 컬럼 표시
pd.set_option('display.max_columns', None)
# 데이터 불러오기
data = pd.read_csv('data/student-mat.csv', delimiter=";")
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         3       yes     no  yes
# 3      home   mother           1          3         0        no    yes  yes
# 4      home   father           1          2         0        no    yes  yes
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 390  course    other           1          2         2        no    yes  yes
# 391  course   mother           2          1         0        no     no   no
# 392  course    other           1          1         3        no     no   no
# 393  course   mother           3          1         0        no     no   no
# 394  course   father           1          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 390         no     yes    yes       no       no       5         5      4
# 391         no      no    yes      yes       no       2         4      5
# 392         no      no    yes       no       no       5         5      3
# 393         no      no    yes      yes       no       4         4      1
# 394         no     yes    yes      yes       no       3         2      3
#
#      Dalc  Walc  health  absences  G1  G2  G3
# 0       1     1       3         6   5   6   6
# 1       1     1       3         4   5   5   6
# 2       2     3       3        10   7   8  10
# 3       1     1       5         2  15  14  15
# 4       1     2       5         4   6  10  10
# ..    ...   ...     ...       ...  ..  ..  ..
# 390     4     5       4        11   9   9   9
# 391     3     4       2         3  14  16  16
# 392     3     3       3         3  10   8   7
# 393     3     4       5         0  11  12  10
# 394     3     3       5         5   8   9   9
#
# [395 rows x 33 columns]

# %% [markdown]
# - 문제, 정답 분리

# %%
X = data['studytime']
y = data['G3']

# %%
X.shape , y.shape
# Out:
# ((395,), (395,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=16)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((296,), (99,), (296,), (99,))

# %% [markdown]
# ### 신경망 모듈 만들기
# 1. 신경망 구조 설계
# 2. 신경망 학습 및 평가 방법 설정
# 3. 학습 및 학습과정 시각화
# 4. 모델 평가

# %%
# 신경망의 뼈대를 구축하기 위한 함수
from tensorflow.keras import Sequential

# inputLayer : 신경망 입력층을 생성
# Dense : 신경망 층(뉴런의 묶음)을 구성해주는 함수
from tensorflow.keras.layers import InputLayer, Dense

# %%
# 1. 신경망 구조 설계
# 신경망 뼈대 설정
model = Sequential()

# 입력층 설정
# input_shape : 입력데이터의 특성 형태를 설정(1개의 특성을 가진 1차원 데이터)
model.add(InputLayer(input_shape=(1,)))

# 출력층 설정
# Dense : 하나의 층을 쌓아주는 함수(괄호 안의 숫자는 해당 층에 있는 뉴런의 개수)
model.add(Dense(1))

# 설계된 신경망의 정보를 요약해서 출력
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2. 신경망 학습 및 평가 방법 설정
# 손실함수(비용함수), 최적화 함수 설정
model.compile(
    loss = 'mse',
    optimizer='SGD'
)

# %%
# 3. 학습 및 시각화
h = model.fit(X_train, y_train, epochs=100)
#epochs : 학습 횟수 설정
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 4ms/step - loss: 49.0010
# Epoch 2/100
# 10/10 [==============================] - 0s 2ms/step - loss: 31.3085
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 29.3123
# Epoch 4/100
# 10/10 [==============================] - 0s 2ms/step - loss: 28.7139
# Epoch 5/100
# 10/10 [==============================] - 0s 2ms/step - loss: 28.3587
# Epoch 6/100
# 10/10 [==============================] - 0s 2ms/step - loss: 28.0488
# Epoch 7/100
# 10/10 [==============================] - 0s 3ms/step - loss: 27.6891
# Epoch 8/100
# 10/10 [==============================] - 0s 2ms/step - loss: 27.4084
# Epoch 9/100
# 10/10 [==============================] - 0s 3ms/step - loss: 27.1102
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 26.8035
# Epoch 11/100
# 10/10 [==============================] - 0s 2ms/step - loss: 26.5196
# Epoch 12/100
# 10/10 [==============================] - 0s 2ms/step - loss: 26.2715
# Epoch 13/100
# 10/10 [==============================] - 0s 2ms/step - loss: 26.0007
# Epoch 14/100
# 10/10 [==============================] - 0s 3ms/step - loss: 25.6945
# Epoch 15/100
# 10/10 [==============================] - 0s 2ms/step - loss: 25.4603
# Epoch 16/100
# 10/10 [==============================] - 0s 2ms/step - loss: 25.3384
# Epoch 17/100
# 10/10 [==============================] - 0s 3ms/step - loss: 25.1057
# Epoch 18/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.9260
# Epoch 19/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.7380
# Epoch 20/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.5336
# Epoch 21/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.3444
# Epoch 22/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.2423
# Epoch 23/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.0375
# Epoch 24/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.8833
# Epoch 25/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.7222
# Epoch 26/100
# 10/10 [==============================] - 0s 4ms/step - loss: 23.6216
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.5348
# Epoch 28/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.3586
# Epoch 29/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.2288
# Epoch 30/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.1505
# Epoch 31/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.9740
# Epoch 32/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.8678
# Epoch 33/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.8615
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.7187
# Epoch 35/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.6118
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.5538
# Epoch 37/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.5127
# Epoch 38/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.4233
# Epoch 39/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.3511
# Epoch 40/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.3364
# Epoch 41/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.1890
# Epoch 42/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.1321
# Epoch 43/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.0774
# Epoch 44/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.9618
# Epoch 45/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.9261
# Epoch 46/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.9222
# Epoch 47/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.8398
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.8122
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.8290
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.7083
# Epoch 51/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.6672
# Epoch 52/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.6531
# Epoch 53/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.5586
# Epoch 54/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.5154
# Epoch 55/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.4919
# Epoch 56/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.4374
# Epoch 57/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.4190
# Epoch 58/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.3789
# Epoch 59/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.3691
# Epoch 60/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.3630
# Epoch 61/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.4377
# Epoch 62/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.2980
# Epoch 63/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.4086
# Epoch 64/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.2228
# Epoch 65/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.2628
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.2453
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.1850
# Epoch 68/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.1652
# Epoch 69/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.1349
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.1759
# Epoch 71/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.0679
# Epoch 72/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.0598
# Epoch 73/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.0409
# Epoch 74/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.0478
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.0707
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.0094
# Epoch 77/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.9866
# Epoch 78/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.9823
# Epoch 79/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.9491
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.9586
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.9336
# Epoch 82/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.9375
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.9515
# Epoch 84/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.9688
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.8911
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.8633
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.9000
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.9235
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.0058
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.9381
# Epoch 91/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.9233
# Epoch 92/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.8291
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.8393
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.8435
# Epoch 95/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.8452
# Epoch 96/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.8722
# Epoch 97/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.8445
# Epoch 98/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.8699
# Epoch 99/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.7810
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.7929

# %%
# 3. 학습과정 시각화
plt.figure(figsize=(15,5))
plt.plot(h.history['loss'], label='loss')
plt.legend()
plt.show()

# %% [markdown]
# - 초반에는 빠르게 loss 값(mse)이 떨어지고 있음
# - 경사하강법 초반에는 가중치, 절편값이 임의의 값으로 설정되어 있기 때문에 학습시켜도 mse가 빠르게 줄어드는 것을 볼수 있음

# %%
# 4. 모델평가
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 21.0266
# 21.02656364440918

# %% [markdown]
# ### 입력 특성이 2개인 모델을 직접 만들어보자
# - 문제 (studytime, traveltime) - X1
# - 정답 (G3) - y1
# - 신경망의 최종 출력층 뉴런 개수는 1개

# %%
X1 = data[['studytime','traveltime']]
y1 = data['G3']

# %%
X1.shape, y1.shape
# Out:
# ((395, 2), (395,))

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, random_state=200)

# %%
# 1. 신경망 구조 설계
# 신경망 뼈대 설정
model1 = Sequential()

# 입력층 설정
# input_shape : 입력데이터의 특성 형태를 설정(1개의 특성을 가진 1차원 데이터)
model1.add(InputLayer(input_shape=(2,)))

# 출력층 설정
# Dense : 하나의 층을 쌓아주는 함수(괄호 안의 숫자는 해당 층에 있는 뉴런의 개수)
model1.add(Dense(1))

# 설계된 신경망의 정보를 요약해서 출력
model1.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2. 신경망 학습 및 평가 방법 설정
# 손실함수(비용함수), 최적화 함수 설정
model1.compile(
    loss = 'mse',
    optimizer='SGD'
)

# %%
# 3. 학습 및 시각화
h1 = model1.fit(X1_train, y1_train, epochs=100)
#epochs : 학습 횟수 설정
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 7ms/step - loss: 72.9618
# Epoch 2/100
# 10/10 [==============================] - 0s 4ms/step - loss: 30.7493
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 29.2360
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 28.7464
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 28.5166
# Epoch 6/100
# 10/10 [==============================] - 0s 5ms/step - loss: 28.3861
# Epoch 7/100
# 10/10 [==============================] - 0s 4ms/step - loss: 28.1367
# Epoch 8/100
# 10/10 [==============================] - 0s 5ms/step - loss: 27.8539
# Epoch 9/100
# 10/10 [==============================] - 0s 7ms/step - loss: 27.5761
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 27.5187
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 27.4004
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 27.1639
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 27.1136
# Epoch 14/100
# 10/10 [==============================] - 0s 5ms/step - loss: 26.9049
# Epoch 15/100
# 10/10 [==============================] - 0s 4ms/step - loss: 26.8370
# Epoch 16/100
# 10/10 [==============================] - 0s 4ms/step - loss: 26.6903
# Epoch 17/100
# 10/10 [==============================] - 0s 3ms/step - loss: 26.4808
# Epoch 18/100
# 10/10 [==============================] - 0s 6ms/step - loss: 26.4548
# Epoch 19/100
# 10/10 [==============================] - 0s 4ms/step - loss: 26.2939
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 26.1883
# Epoch 21/100
# 10/10 [==============================] - 0s 3ms/step - loss: 26.1935
# Epoch 22/100
# 10/10 [==============================] - 0s 3ms/step - loss: 25.9350
# Epoch 23/100
# 10/10 [==============================] - 0s 2ms/step - loss: 25.8686
# Epoch 24/100
# 10/10 [==============================] - 0s 4ms/step - loss: 25.7612
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 25.6857
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 25.5161
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 25.4278
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 25.3927
# Epoch 29/100
# 10/10 [==============================] - 0s 3ms/step - loss: 25.2543
# Epoch 30/100
# 10/10 [==============================] - 0s 2ms/step - loss: 25.2948
# Epoch 31/100
# 10/10 [==============================] - 0s 2ms/step - loss: 25.0742
# Epoch 32/100
# 10/10 [==============================] - 0s 2ms/step - loss: 25.0262
# Epoch 33/100
# 10/10 [==============================] - 0s 2ms/step - loss: 25.0890
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 24.8943
# Epoch 35/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.9188
# Epoch 36/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.7005
# Epoch 37/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.6370
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 24.5648
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 24.5288
# Epoch 40/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.4708
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 24.4340
# Epoch 42/100
# 10/10 [==============================] - 0s 3ms/step - loss: 24.3787
# Epoch 43/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.3147
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.1974
# Epoch 45/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.1789
# Epoch 46/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.1467
# Epoch 47/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.0628
# Epoch 48/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.0011
# Epoch 49/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.9337
# Epoch 50/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.9735
# Epoch 51/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.9037
# Epoch 52/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.8172
# Epoch 53/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.7514
# Epoch 54/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.7118
# Epoch 55/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.7097
# Epoch 56/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.6253
# Epoch 57/100
# 10/10 [==============================] - 0s 4ms/step - loss: 23.5681
# Epoch 58/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.5354
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.4969
# Epoch 60/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.4772
# Epoch 61/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.4464
# Epoch 62/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.3935
# Epoch 63/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.3646
# Epoch 64/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.3141
# Epoch 65/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.3021
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.3107
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.2303
# Epoch 68/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.1888
# Epoch 69/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.1998
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.1940
# Epoch 71/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.1265
# Epoch 72/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.1220
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.2633
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.0615
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.0306
# Epoch 76/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.9842
# Epoch 77/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.9613
# Epoch 78/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.9680
# Epoch 79/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.0020
# Epoch 80/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.8985
# Epoch 81/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.8851
# Epoch 82/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.8704
# Epoch 83/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.8371
# Epoch 84/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.8062
# Epoch 85/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.8296
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.8008
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.9480
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.7776
# Epoch 89/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.7790
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.7525
# Epoch 91/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.8220
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.8402
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.6997
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.6331
# Epoch 95/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.6221
# Epoch 96/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.6769
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.6189
# Epoch 98/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.6676
# Epoch 99/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.5777
# Epoch 100/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.6203

# %%
# 3. 학습과정 시각화
plt.figure(figsize=(15,5))
plt.plot(h1.history['loss'], label='loss')
plt.legend()
plt.show()

# %%
# 4. 모델평가
model1.evaluate(X1_test, y1_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 16.2949
# 16.294946670532227
