# %% [markdown]
# ### 문제1. 다음은 어떤 차트에 대한 설명이다. 각 번호에 알맞은 답을 작성하시오.
# ### [ ① ]은(는) x, y축의 값들에 따라 꺾은선 그래프로 표현한 차트이다. matplotlib.pyplot의 [ ② ] 함수를 이용해서 [ ① ]을(를) 간단하게 표현할 수 있다. x축에 따른 y축 값의 변화 추이를 한눈에 볼 수 있다는 장점이 있다.

# %% [markdown]
# 1. 플롯차트 (plot chart)
# 2. plot

# %% [markdown]
# ### 문제2. 다음은 어떤 차트에대한 출력결과이다. 문제를 읽고 알맞은 답을 작성하시오.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (1) 이 차트의 명칭을 작성하시오.

# %% [markdown]
# bar차트

# %% [markdown]
# ### (2) 이 차트를 그리기 위해 어떤 함수를 사용하는지 작성하시오

# %% [markdown]
# bar 함수

# %% [markdown]
# ### 문제3. <실행결과> 같은 결과를 출력하는 코드를 완성하시오. (단, 두 차트는 빨간색과 파란색을 통해 구분지어야 한다.)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import rc
rc('font', family = 'Malgun Gothic')

# %%
X = [2,3,4,5,6,7,8]
Y1 = [5,7,3,9,1,8,6]
Y2 = [9,5,7,2,3,7,1]

# %%
plt.plot(X, Y1, label='Y1', c = 'r')
plt.plot(X, Y2, label='Y2', c = 'b')
plt.grid()
plt.legend(loc="upper right", prop={'size':7})
plt.title("<실행결과>")
plt.xlabel("X")
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ### 문제4. Traffic_Accident_2017.csv 데이터를 이용하여 주간과 야간에 발생한 사건에 대해 아래 주어진 조건을 지켜 다음과 같이 시각화 하시오.
# - 조건 1. 사고유형이 ‘차대사람’ 이면서 발생시간대가 ‘야간’인 경우의 사고 건수 카운트
# - 조건 2. y축의 범위는 0~200으로 설정할 것
# - 조건 3. 차트 내부 글씨는 한글로 표시할 것

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = pd.read_csv('data/Traffic_Accident_2017.csv', encoding='euc-kr')
data
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 0     2017  2017010101   15  야간  일     1     2     1     0       0  ...
# 1     2017  2017010102   28  야간  일     1     1     0     0       0  ...
# 2     2017  2017010102   43  야간  일     1     2     0     1       0  ...
# 3     2017  2017010102   22  야간  일     1     1     0     0       0  ...
# 4     2017  2017010104   37  야간  일     1     1     0     0       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4060  2017  2017123118   10  야간  일     1     4     1     0       2  ...
# 4061  2017  2017123118   25  야간  일     1     1     0     0       0  ...
# 4062  2017  2017123119   55  야간  일     1     1     0     0       0  ...
# 4063  2017  2017123120   40  야간  일     1    11     1     9       0  ...
# 4064  2017  2017123123   15  야간  일     1     1     0     0       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류  당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
acc = data[data['사고유형_대분류'] == "차대사람"]
acc
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 1     2017  2017010102   28  야간  일     1     1     0     0       0  ...
# 4     2017  2017010104   37  야간  일     1     1     0     0       0  ...
# 5     2017  2017010104    0  야간  일     1     2     1     0       0  ...
# 6     2017  2017010105   50  야간  일     1     1     0     0       0  ...
# 11    2017  2017010203   30  야간  월     1     2     0     1       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4053  2017  2017123018   36  야간  토     1     1     0     0       0  ...
# 4056  2017  2017123100   50  야간  일     1     1     0     0       0  ...
# 4057  2017  2017123107    4  주간  일     1     1     0     0       0  ...
# 4059  2017  2017123117   56  주간  일     1     1     0     0       0  ...
# 4064  2017  2017123123   15  야간  일     1     1     0     0       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
days = acc[acc['주야']=='야간']['요일'].value_counts()

# %%
days = days.reindex(['월','화','수','목','금','토','일'])

# %%
x = np.arange(len (days))
y = days

# %%
plt.bar(x,y)
plt.title("요일별 야간 차대사람 교통사고 건수 ")
plt.xlabel("요일")
plt.xticks(np.arange(7),labels=['월', '화', '수', '목', '금', '토', '일'])
plt.ylabel("사고건수")
plt.ylim(0,200)

plt.show()
